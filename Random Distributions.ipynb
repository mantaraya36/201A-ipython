# %% [markdown]
# # Random Distributions

# %%
# %pylab inline
rcParams['figure.figsize'] = (10, 4) #wide graphs by default
from __future__ import print_function
from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
random.random(4)
# Out:
# array([ 0.61974206,  0.26986707,  0.55367968,  0.7785527 ])

# %%
random.random( (4,4) )
# Out:
# array([[ 0.54335387,  0.80959876,  0.33900397,  0.74016663],
#        [ 0.83177602,  0.62556786,  0.91562183,  0.15425722],
#        [ 0.94937041,  0.08872609,  0.68688227,  0.91227525],
#        [ 0.94632064,  0.01259696,  0.40422814,  0.81177241]])

# %%
mat = random.random((4,4))

# %%
sig = random.random(100)
plot(sig)

# %%
sig = (random.random(100)*2) - 1
plot(sig)

# %% [markdown]
# ## Mean, median, mode

# %%
mean(sig)
# Out:
# 0.074954249955294705

# %%
random.random(10000).mean()
# Out:
# 0.49380265893108988

# %%
random.random(100000).mean()
# Out:
# 0.50051557855533191

# %%
random.random(10000000).mean()
# Out:
# 0.50003303155206391

# %%
randint(1, 7, 10)
# Out:
# array([3, 5, 2, 3, 6, 4, 3, 4, 4, 6])

# %%
randint(1, 21, 10)
# Out:
# array([ 2, 20,  7, 13, 13,  2,  3,  1, 18, 15])

# %%
randint(1, 7, 10).mean()
# Out:
# 2.6000000000000001

# %%
randint(1, 7, 1000).mean()
# Out:
# 3.4820000000000002

# %%
die_throws = randint(1, 7, 1000)

# %%
from scipy.stats import mode
mode(die_throws)
# Out:
# (array([ 2.]), array([ 175.]))

# %%
sig = array ([13, 18, 13, 14, 13, 16, 14, 21, 13])
sig.mean()
# Out:
# 15.0

# %%
sig.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-3bcafa1ac3fb> in <module>()
# ----> 1 sig.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
mean(sig), median(sig)
# Out:
# (15.0, 14.0)

# %%
sort(sig)
# Out:
# array([13, 13, 13, 13, 14, 14, 16, 18, 21])

# %%
hist(sig);

# %%
mode(sig)
# Out:
# (array([ 13.]), array([ 4.]))

# %%
sig = r_[13, 18, 13, 14, 13, 16, 14, 21, 13, 18, 18, 18]
mode(sig)
# Out:
# (array([ 13.]), array([ 4.]))

# %% [markdown]
# ## Probability distributions

# %%
normal()
# Out:
# -1.4042329021398916

# %%
sig = normal(size=100)
plot(sig)

# %%
mat = normal(size=(128,128))
subplot(121)
imshow(mat)
colorbar()
mat = random.random(size=(128,128))
subplot(122)
imshow(mat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f092a8d0950>

# %%
#from numpy.random import *

# %%
randint(1,7, 10)
die = randint(1,7, 10)
die
hist(die)
# Out:
# (array([ 1.,  0.,  2.,  0.,  2.,  0.,  2.,  0.,  0.,  3.]),
#  array([ 1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,  5.5,  6. ]),
#  <a list of 10 Patch objects>)

# %%
die = randint(1,7, 10)
hist(die);

# %%
hist(die, bins= (arange(7)+0.5))
# Out:
# (array([ 1.,  1.,  0.,  4.,  3.,  1.]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5]),
#  <a list of 6 Patch objects>)

# %%
die = randint(1,7, 100)
hist(die, bins= (arange(7)+0.5))
# Out:
# (array([ 19.,  18.,  20.,  13.,  18.,  12.]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5]),
#  <a list of 6 Patch objects>)

# %%
die = randint(1,7, 10000)
hist(die, bins= (arange(7)+0.5));

# %%
r = normal(0, 1, 10)
hist(r);

# %%
r = normal(0, 1, 100)
hist(r);

# %%
r = normal(0, 1, 10000)
hist(r);

# %%
hist(r, 31);

# %%
r = normal(0, 5, 10000)
hist(r, 31);

# %%
r = normal(0, 1, 10000)
hist(r);

# %%
hist(r, 30);

# %%
r = normal(0, 5, 10000)
type(r)
# Out:
# numpy.ndarray

# %%
hist(r, 31)
print(r.std(), r.var())
# Out:
# 5.04661277196 25.4683004701

# %%
r = exponential(1, 10000)
hist(r, 30);

# %%
r = exponential(2, 10000)
hist(r, 30);

# %%
r = exponential(10, 10000)
hist(r, 30);

# %%
r = exponential(1, 10000)
hist(r, 30);

# %%
r = triangular(0,0, 5, 10000)
hist(r);

# %%
hist(r,30);

# %%
r = triangular(left=1, mode=3, right=9, size=10000)
hist(r);

# %%
hist(r,31);

# %%
r = gamma(1, 2, 10000)
hist(r,30);

# %%
r = gamma(5, 1, 10000)
hist(r,30);

# %%
r = poisson(1, 10000)
hist(r,30);

# %%
r = poisson(10, 10000)
hist(r,30);

# %%
binomial(100, 1.0/6.0)
# Out:
# 11

# %%
100.0/6
# Out:
# 16.666666666666668

# %%
print(binomial(10000, 1.0/6.0))
r = binomial(10000, 1.0/6.0, 10000)
# Out:
# 1679

# %%
hist(r,30);

# %%
hist(sig);

# %% [markdown]
# ## Probability density/mass functions

# %%
from scipy import  stats
quantiles = linspace(-0.5,1.5, 100)
plot(quantiles, stats.uniform.pdf(quantiles))
ylim((0, 1.1))
# Out:
# (0, 1.1)

# %%
quantiles = linspace(-4.5,4.5, 1024)
plot(quantiles, stats.norm.pdf(quantiles))
ylim((0, 1.1))
# Out:
# (0, 1.1)

# %%
quantiles = arange(50)

plot(quantiles, stats.poisson.pmf(quantiles, 0.2), 'o-')
plot(quantiles, stats.poisson.pmf(quantiles, 5), 'o-')
plot(quantiles, stats.poisson.pmf(quantiles, 20), 'o-')
legend(['$\lambda$ = 0.2','$\lambda$ = 5','$\lambda$ = 20'])

# %% [markdown]
# By: Andrés Cabrera mantaraya36@gmail.com
# For MAT course MAT 201A at UCSB
#
# This ipython notebook is licensed under the CC-BY-NC-SA license: http://creativecommons.org/licenses/by-nc-sa/4.0/
#
# ![http://i.creativecommons.org/l/by-nc-sa/3.0/88x31.png](http://i.creativecommons.org/l/by-nc-sa/3.0/88x31.png)
