# %%
from scipy.io import wavfile

# %%
sample = wavfile.read('passport.wav')

# %%
img = imread('python.jpeg')

# %%
imshow(img, cmap=cm.gray)

# %%
imshow(sum(img, axis=2), cmap=cm.gray)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3b794d0>

# %%
imshow(sum(img, axis=2))
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x40278c0>

# %%
img.shape
# Out:
# (230, 219, 3)

# %%
imshow(img[:,:,0], cmap=cm.gray)

# %%
imshow(img[:,:,1], cmap=cm.gray)

# %%
sig = img[100,:, 1]
plot(sig)
sig.dtype
# Out:
# dtype('uint8')

# %%
sigout = list((sig - 100) * 200)*30
plot(sigout)

# %% [markdown]
# What?!?!

# %%
sig.dtype
# Out:
# dtype('uint8')

# %%
sigout = list((sig.astype(int16) - 100) * 200)*30
plot(sigout)

# %%
wavfile.write('outsig.wav', 44100, array(sigout, dtype=int16))

# %%
a = array([[1,2,3],[4,5,6]])
b = array(a.flat)
b
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
audioout = array(((img[:,:,0].astype(int16)- 100) * 200).flat)
wavfile.write('outsig.wav', 44100, audioout)

# %%
audioout = array(((img[:,:,0].astype(int16)- 100) * 200).flat)
wavfile.write('outsig.wav', 8000, audioout)

# %%
sr,sample = wavfile.read('passport.wav')

# %%
sample.size
# Out:
# 331098

# %%
256 * 256 * 3
# Out:
# 196608

# %%
newimg = sample[:196608].reshape(256,256,3)

# %%
imshow(newimg)

# %%
256*512
# Out:
# 131072

# %%
newimg = sample[:256*512].reshape(256,512)
imshow(newimg, cmap=cm.cool)

# %%
imsave('outimg.jpg', newimg, cmap=cm.cool)

# %% [markdown]
# More colormaps:
#
# http://matplotlib.org/examples/color/colormaps_reference.html

# %%
newimgR = sample[:256*512].reshape(256,512, 1)
newimgG = sample[10:256*512 + 10].reshape(256,512, 1)
newimgB = sample[100:256*512 + 100].reshape(256,512, 1)
newimg = concatenate( [newimgR, newimgG, newimgB], axis = 2)
print newimg.shape
# Out:
# (256, 512, 3)

# %%
imshow(newimg)

# %%
imshow(newimg[:,:,0])

# %%
imshow(newimg[:,:,1])

# %%
imshow(newimg.astype(float)/1000)

# %%
imshow(newimg/100)

# %%
newimgR = sample[:256*512].reshape(256,512, 1)
newimgG = sample[4:256*512 + 4
].reshape(256,512, 1)
newimgB = sample[1:256*512 + 1].reshape(256,512, 1)
newimg = concatenate( [newimgR, newimgG, newimgB], axis = 2)
print newimg.shape
# Out:
# (256, 512, 3)

# %%
imshow(newimg)

# %%
rgrids
