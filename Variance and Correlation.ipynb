# %%
# %pylab inline
rcParams['figure.figsize'] = (10, 4) #wide graphs by default
from __future__ import print_function
from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Variance and correlation

# %% [markdown]
# ![http://imgs.xkcd.com/comics/random_number.png](http://imgs.xkcd.com/comics/random_number.png)

# %% [markdown]
# ![http://imgs.xkcd.com/comics/sports.png](http://imgs.xkcd.com/comics/sports.png)

# %% [markdown]
# ![http://imgs.xkcd.com/comics/cell_phones.png](http://imgs.xkcd.com/comics/cell_phones.png)

# %% [markdown]
# [http://xkcd.com/882/](http://xkcd.com/882/)

# %% [markdown]
# ## Variance and covariance

# %% [markdown]
# $$\operatorname{Var}(X) =\sigma^2 =\int (x-\mu)^2  f(x)  dx =\int x^2  f(x)  dx - \mu^2$$
#
# $$\operatorname{Var}(X) = \sum_{i=1}^n p_i\cdot(x_i - \mu)^2 = \sum_{i=1}^n (p_i\cdot x_i^2) - \mu^2$$
#
# http://en.wikipedia.org/wiki/Variance
#
# For equally likely values:
#
# $$\operatorname{Var}(X) = \frac{1}{n} \sum_{i=1}^n (x_i - \mu)^2$$

# %%
samps = normal(scale=2.0, size= 10000)
samps.var()
# Out:
# 3.998881078800586

# %%
samps.std(), samps.std()**2
# Out:
# (1.9997202501351499, 3.9988810788005864)

# %%
a = rand(100)
b = rand(100)
cov(a,b)
# Out:
# array([[ 0.0825884 , -0.00359315],
#        [-0.00359315,  0.09947109]])

# %%
a = rand(100)* 100
b = rand(100) * 100
cov(a,b)
# Out:
# array([[ 896.37360137,  -81.92130913],
#        [ -81.92130913,  829.65039729]])

# %%
a = rand(100000)* 100
b = rand(100000) * 100
cov(a,b)
# Out:
# array([[ 830.75775195,    0.96796568],
#        [   0.96796568,  833.98690858]])

# %%
var(a), var(b)
# Out:
# (830.74944436760131, 833.97856871063163)

# %%
a = rand(100)
b = rand(100)
c = rand(100)
cov(a + (2*c),b + (2*c))
# Out:
# array([[ 0.39432456,  0.35143268],
#        [ 0.35143268,  0.45321349]])

# %%
a = rand(100000)
b = rand(100000)
c = rand(100000)
cov(a + (2*c),b + (2*c))
# Out:
# array([[ 0.41893971,  0.33550546],
#        [ 0.33550546,  0.41893778]])

# %%
a = rand(100)
b = rand(100)
d = sin(linspace(0, 2*pi*7, 100))
plot(a+d)
plot(b+d)

# %%
cov(a + d,b + d)
# Out:
# array([[ 0.56611936,  0.48289796],
#        [ 0.48289796,  0.53855619]])

# %%
plot(a+d + 2)
plot(-2*(b+d))
cov(a + d + 2,-2*(b+d))
# Out:
# array([[ 0.56611936, -0.96579591],
#        [-0.96579591,  2.15422476]])

# %%
plot(a + (d*3))
plot(b + (d*3))

# %%
cov(a + (d*3),b + (d*3))
# Out:
# array([[ 4.52952965,  4.41339103],
#        [ 4.41339103,  4.43613205]])

# %% [markdown]
# ## Correlation and autocorrelation

# %% [markdown]
# $$(f \star g)(\tau)\ \stackrel{\mathrm{def}}{=} \int_{-\infty}^{\infty} f^*(t)\ g(t+\tau)\,dt$$
#
# $$ (f \star g)(n) = \frac{1}{N} \sum_{i=1}^N f(i) . g(i + n)$$
# $$

# %%
sig1 = sin(linspace(0, 100*2*pi, 44100))
sig2 = sin(linspace(0.1, 0.1 + (100*2*pi), 44100))
plot(sig1)
plot(sig2)
xlim((0, 2000))
# Out:
# (0, 2000)

# %%
lags, c, lines, line = xcorr(sig1, sig2, maxlags=500, usevlines=False);
grid()

# %%
lags, c, lines, line = xcorr(sig1, sig2, maxlags=50, usevlines=False);
grid()

# %%
argmax(c)
# Out:
# 57

# %%
cc_index = lags[argmax(c)]
print(cc_index)
# Out:
# 7

# %%
plot(lags, c)
vlines(cc_index, 0.5, 1.09, color='r', lw=2)
text(cc_index + 1, 1.05, 'CC peak', color='r')
grid()

# %%
sr = 44100
f = 100.0
Ps = sr/f
Ps # period in number of samples
# Out:
# 441.0

# %%
cc_index
# Out:
# 7

# %% [markdown]
# CC can be used to determine pitch and periodicity.

# %%
cc_index/Ps
# Out:
# 0.015873015873015872

# %%
2 * pi * cc_index/Ps
# Out:
# 0.09973310011396169

# %%
2 * pi * (cc_index + 1)/Ps
# Out:
# 0.11398068584452764

# %% [markdown]
# Two different noise samples produce low values of cross-correlation:

# %%
noise1 = random.random(44100) - 0.5
noise2 = random.random(44100) - 0.5

# %%
lags, c, lines, line = xcorr(noise1, noise2, maxlags=500, usevlines=False);
grid()

# %% [markdown]
# And no clear patterns in the CC function:

# %%
noise1 = normal(size=44100)
noise2 = normal(size=44100)

# %%
lags, c, lines, line = xcorr(noise1, noise2, maxlags=500, usevlines=False);
grid()

# %% [markdown]
# Cross-correlation can find harder to see relationships:

# %%
a = (rand(44100)*2) - 1
plot(a)

# %%
b = sin(linspace(0, 2*pi*200, 44100))*0.3
plot(a+b)

# %%
c = (rand(44100)*2) - 1
d = sin(linspace(0.7, 0.7 + (2*pi*200), 44100))*0.3
plot(c+d)

# %%
plot(c+d)
xlim(0,1000)
# Out:
# (0, 1000)

# %%
lags, c, lines, line = xcorr(a+b, c+d, maxlags=500);

# %%
m = argmax(c[500:600]) + 500

# %%
lags[m]
# Out:
# 23

# %%
sr = 44100
f = 200.0
Ps = sr/f
Ps # period in number of samples
# Out:
# 220.5

# %%
lags[m]/Ps
# Out:
# 0.10430839002267574

# %%
(lags[m]/Ps) * 2 * pi
# Out:
# 0.65538894360603395

# %% [markdown]
# # Autocorrelation

# %%
lags, c, lines, line = acorr(a + b, maxlags=500);

# %%
plot(c[501:])
vlines(220.5, -0.15, 0.15)

# %% [markdown]
# CC for Inter-aural time delay (or stereo relationships) using running cross-correlation

# %%
from scipy.io import wavfile

# %%
sr, in_sig = wavfile.read('cars.wav')

# %%
win_size = 1024
hop = 256

cc_lags = 0.001*sr # 1 ms max lag

rccf = []
win_start = arange(0, in_sig.shape[0] - win_size, hop)
for start in win_start:
    win = in_sig[start: start+win_size].astype(float)
    lags, c, lines, line = xcorr(win[:,0], win[:,1], maxlags=cc_lags)
    rccf.append(c)

# %%
imshow(array(rccf).T, aspect='auto')

# %%
plot(in_sig)
# Out:
# [<matplotlib.lines.Line2D at 0x7f6792ae32d0>,
#  <matplotlib.lines.Line2D at 0x7f6792ae3550>]

# %% [markdown]
# CC for tempo and rhythm estimation:

# %%
sr, in_sig = wavfile.read('superstition.wav')

# %%
plot(in_sig)
# Out:
# [<matplotlib.lines.Line2D at 0x7f6792a2b310>,
#  <matplotlib.lines.Line2D at 0x7f6792a2b590>]

# %%
in_sig.shape
# Out:
# (437078, 2)

# %%
lags,c, lines, line = acorr(in_sig[:100000,0].astype(double), maxlags= 50000);

# %% [markdown]
# ## Two-dimensional cross-correlation

# %% [markdown]
# ![sidereusnuncius_crawford_dbyn2008.jpg](sidereusnuncius_crawford_dbyn2008.jpg)

# %%
i = imread('galileo.png')
imshow(i)

# %%
i.shape
# Out:
# (1213, 780, 4)

# %%
i.dtype
# Out:
# dtype('float32')

# %%
i = sum(i.astype(float), axis=2)/4.0
imshow(i)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f679dfaaa28>

# %%
i.shape
# Out:
# (1213, 780)

# %%
imshow(i)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f67aa9e8440>

# %%
imshow(i, cmap=cm.gray)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f67a71d24d0>

# %%
i = where(i > 0.9, -1, 1)
imshow(i, cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f67aa019a28>

# %%
o = imread('o.png')
imshow(o)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f67af75ad88>

# %%
o = o.astype(float).sum(axis=-1)/3
o = where(o > 0.9, 1, -1)
imshow(o, cmap=cm.gray, interpolation='nearest')

# %%
from scipy.signal import correlate2d
cc = correlate2d(i, o)
imshow(cc)
colorbar()
gcf().set_figheight(8)

# %%
imshow(cc, cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
imshow(where(cc > 200, 1, 0), interpolation='nearest', cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
imshow(where(cc > 1000, 1, 0), interpolation='nearest', cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
from scipy.ndimage.filters import maximum_filter

imshow(maximum_filter(cc, (10,10)))
gcf().set_figheight(8)

# %%
subplot(121)
imshow(maximum_filter(cc, (50,50)))
subplot(122)
imshow(i, cmap=cm.gray)
gcf().set_figheight(8)

# %%
mf = maximum_filter(cc, (50,50))

# %%
argmax(mf)
# Out:
# 215823

# %%
unravel_index(argmax(mf), mf.shape)
# Out:
# (262, 721)

# %%
argmax(cc)
# Out:
# 235551

# %%
unravel_index(argmax(cc), cc.shape)
# Out:
# (286, 745)

# %% [markdown]
# By: Andrés Cabrera mantaraya36@gmail.com
# For MAT course MAT 201A at UCSB
#
# This ipython notebook is licensed under the CC-BY-NC-SA license: http://creativecommons.org/licenses/by-nc-sa/4.0/
#
# ![http://i.creativecommons.org/l/by-nc-sa/3.0/88x31.png](http://i.creativecommons.org/l/by-nc-sa/3.0/88x31.png)
