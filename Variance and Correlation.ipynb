# %% [markdown]
# # Variance and correlation

# %% [markdown]
# ![http://imgs.xkcd.com/comics/random_number.png](http://imgs.xkcd.com/comics/random_number.png)

# %% [markdown]
# ![http://imgs.xkcd.com/comics/sports.png](http://imgs.xkcd.com/comics/sports.png)

# %% [markdown]
# ![http://imgs.xkcd.com/comics/cell_phones.png](http://imgs.xkcd.com/comics/cell_phones.png)

# %% [markdown]
# [http://xkcd.com/882/](http://xkcd.com/882/)

# %%
rcParams['figure.figsize'] = (16, 4) #wide graphs by default

# %% [markdown]
# ## Variance and covariance

# %% [markdown]
# $$\operatorname{Var}(X) =\sigma^2 =\int (x-\mu)^2  f(x)  dx =\int x^2  f(x)  dx - \mu^2$$
#
# $$\operatorname{Var}(X) = \sum_{i=1}^n p_i\cdot(x_i - \mu)^2 = \sum_{i=1}^n (p_i\cdot x_i^2) - \mu^2$$
#
# http://en.wikipedia.org/wiki/Variance
#
# For equally likely values:
#
# $$\operatorname{Var}(X) = \frac{1}{n} \sum_{i=1}^n (x_i - \mu)^2$$

# %%
samps = normal(scale=2.0, size= 10000)
samps.var()
# Out:
# 3.9611355123302086

# %%
samps.std(), samps.std()**2
# Out:
# (1.990260161971346, 3.9611355123302086)

# %%
a = rand(100)
b = rand(100)
cov(a,b)
# Out:
# array([[ 0.08807762, -0.0077181 ],
#        [-0.0077181 ,  0.08125478]])

# %%
a = rand(100)* 100
b = rand(100) * 100
cov(a,b)
# Out:
# array([[ 688.90089579,  -39.35379164],
#        [ -39.35379164,  760.98658063]])

# %%
a = rand(100000)* 100
b = rand(100000) * 100
cov(a,b)
# Out:
# array([[ 834.79033815,   -2.00913137],
#        [  -2.00913137,  833.98300127]])

# %%
var(a), var(b)
# Out:
# (0.087196842748698572, 0.080442232559866544)

# %%
a = rand(100)
b = rand(100)
c = rand(100)
cov(a + (2*c),b + (2*c))
# Out:
# array([[ 0.35748582,  0.25102324],
#        [ 0.25102324,  0.32942145]])

# %%
a = rand(100000)
b = rand(100000)
c = rand(100000)
cov(a + (2*c),b + (2*c))
# Out:
# array([[ 0.41616233,  0.33429107],
#        [ 0.33429107,  0.41828373]])

# %%
a = rand(100)
b = rand(100)
d = sin(linspace(0, 2*pi*7, 100))
plot(a+d)
plot(b+d)

# %%
cov(a + d,b + d)
# Out:
# array([[ 0.59107107,  0.52613742],
#        [ 0.52613742,  0.62117638]])

# %%
plot(a+d + 2)
plot(-2*(b+d))
cov(a + d + 2,-2*(b+d))
# Out:
# array([[ 0.59107107, -1.05227485],
#        [-1.05227485,  2.48470551]])

# %%
plot(a + (d*3))
plot(b + (d*3))

# %%
cov(a + (d*3),b + (d*3))
# Out:
# array([[ 4.59622257,  4.56737053],
#        [ 4.56737053,  4.69849108]])

# %% [markdown]
# ## Correlation and autocorrelation

# %% [markdown]
# $$(f \star g)(t)\ \stackrel{\mathrm{def}}{=} \int_{-\infty}^{\infty} f^*(\tau)\ g(t+\tau)\,d\tau$$

# %%
sig1 = sin(linspace(0, 100*2*pi, 44100))
sig2 = sin(linspace(0.1, 0.1 + (100*2*pi), 44100))
plot(sig1)
plot(sig2)
xlim((0, 5000))
# Out:
# (0, 5000)

# %%
lags, c, lines, line = xcorr(sig1, sig2, maxlags=500, usevlines=False);
grid()

# %%
lags, c, lines, line = xcorr(sig1, sig2, maxlags=50, usevlines=False);
grid()

# %%
argmax(c)
# Out:
# 57

# %%
cc_index = lags[argmax(c)]
print cc_index
# Out:
# 7

# %%
plot(lags, c)
vlines(cc_index, 0.5, 1.09, color='r', lw=2)
text(cc_index + 1, 1.05, 'CC peak', color='r')
grid()

# %%
sr = 44100
f = 100.0
Ps = sr/f
Ps # period in number of samples
# Out:
# 441.0

# %%
cc_index
# Out:
# 7

# %% [markdown]
# CC can be used to determine pitch and periodicity.

# %%
cc_index/Ps
# Out:
# 0.015873015873015872

# %%
2 * pi * cc_index/Ps
# Out:
# 0.099733100113961692

# %%
2 * pi * (cc_index + 1)/Ps
# Out:
# 0.11398068584452764

# %% [markdown]
# Two different noise samples produce low values of cross-correlation:

# %%
noise1 = random.random(44100) - 0.5
noise2 = random.random(44100) - 0.5

# %%
lags, c, lines, line = xcorr(noise1, noise2, maxlags=500, usevlines=False);
grid()

# %% [markdown]
# And no clear patterns in the CC function:

# %%
noise1 = normal(size=44100)
noise2 = normal(size=44100)

# %%
lags, c, lines, line = xcorr(noise1, noise2, maxlags=500, usevlines=False);
grid()

# %% [markdown]
# Cross-correlation can find harder to see relationships:

# %%
a = (rand(44100)*2) - 1
plot(a)

# %%
b = sin(linspace(0, 2*pi*200, 44100))*0.3
plot(a+b)

# %%
c = (rand(44100)*2) - 1
d = sin(linspace(0.7, 0.7 + (2*pi*200), 44100))*0.3
plot(c+d)

# %%
lags, c, lines, line = xcorr(a+b, c+d, maxlags=500);

# %%
m = argmax(c[500:600]) + 500

# %%
lags[m]
# Out:
# 22

# %%
sr = 44100
f = 200.0
Ps = sr/f
Ps # period in number of samples
# Out:
# 220.5

# %%
lags[m]/Ps
# Out:
# 0.099773242630385492

# %%
(lags[m]/Ps) * 2 * pi
# Out:
# 0.62689377214490205

# %%
lags, c, lines, line = acorr(a+b, maxlags=500);

# %%
plot(c[501:])
vlines(220.5, -0.15, 0.15)

# %% [markdown]
# CC for Inter-aural time delay (or stereo relationships) using running cross-correlation

# %%
from scipy.io import wavfile

# %%
sr, in_sig = wavfile.read('cars.wav')

# %%
win_size = 1024
hop = 256

cc_lags = 0.001*sr # 1 ms max lag

rccf = []
win_start = arange(0, in_sig.shape[0] - win_size, hop)
for start in win_start:
    win = in_sig[start: start+win_size].astype(float)
    lags, c, lines, line = xcorr(win[:,0], win[:,1], maxlags=cc_lags)
    rccf.append(c)

# %%
imshow(array(rccf).T, aspect='auto')

# %%
plot(in_sig)
# Out:
# [<matplotlib.lines.Line2D at 0x5c510650>,
#  <matplotlib.lines.Line2D at 0x5cd20ed0>]

# %% [markdown]
# CC for tempo and rhythm estimation:

# %%
sr, in_sig = wavfile.read('superstition.wav')
# Out:
# /usr/lib/python2.7/dist-packages/scipy/io/wavfile.py:121: WavFileWarning: chunk not understood
#   warnings.warn("chunk not understood", WavFileWarning)

# %%
plot(in_sig)
# Out:
# [<matplotlib.lines.Line2D at 0x5ee10890>,
#  <matplotlib.lines.Line2D at 0x5ee10b10>]

# %%
in_sig.shape
# Out:
# (437078, 2)

# %%
lags,c, lines, line = acorr(in_sig[:100000,0].astype(double), maxlags= 50000);

# %% [markdown]
# ## Two-dimensional cross-correlation

# %% [markdown]
# ![sidereusnuncius_crawford_dbyn2008.jpg](sidereusnuncius_crawford_dbyn2008.jpg)

# %%
i = imread('galileo.png')
imshow(i)

# %%
i.shape
# Out:
# (1213, 780, 4)

# %%
i.dtype
# Out:
# dtype('float64')

# %%
i = sum(i.astype(float), axis=2)/4.0
imshow(i)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xe597488>

# %%
i.shape
# Out:
# (1213, 780)

# %%
imshow(i)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x233313f8>

# %%
imshow(i, cmap=cm.gray)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3958ddd0>

# %%
i = where(i > 0.9, 0, 1)
imshow(i, cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x444c4a28>

# %%
o = imread('o.png')
imshow(o)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x63675950>

# %%
o = o.astype(float).sum(axis=-1)/3
o = where(o > 0.9, 0, 1)
imshow(o, cmap=cm.gray, interpolation='nearest')

# %%
from scipy.signal import correlate2d
cc = correlate2d(i, o)
imshow(cc)
colorbar()
gcf().set_figheight(8)
# Out:
# /usr/lib/python2.7/dist-packages/scipy/signal/signaltools.py:467: ComplexWarning: Casting complex values to real discards the imaginary part
#   return sigtools._convolve2d(in1, in2, 0, val, bval, fillvalue)

# %%
imshow(cc, cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
imshow(where(cc > 200, 1, 0), interpolation='nearest', cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
imshow(where(cc > 300, 1, 0), interpolation='nearest', cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
from scipy.ndimage.filters import maximum_filter

imshow(maximum_filter(cc, (10,10)))
gcf().set_figheight(8)

# %%
subplot(121)
imshow(maximum_filter(cc, (50,50)))
subplot(122)
imshow(i, cmap=cm.gray)
gcf().set_figheight(8)

# %%
mf = maximum_filter(cc, (50,50))

# %%
argmax(mf)
# Out:
# 215823

# %%
unravel_index(argmax(mf), mf.shape)
# Out:
# (262, 721)

# %%
argmax(cc)
# Out:
# 235551

# %%
unravel_index(argmax(cc), cc.shape)
# Out:
# (286, 745)
